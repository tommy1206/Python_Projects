# %% [markdown]
# ![A laptop screen with a person typing the word 'seo'](work_laptop.png)

# %% [markdown]
# Imagine working for a digital marketing agency, and the agency is approached by a massive online furniture retailer. They want to test your skills at creating large campaigns for all of their website. You are tasked with creating a prototype set of keywords for search campaigns for their sofas section. The client says that they want you to generate keywords for the following products:
#
# - sofas
# - convertible sofas
# - love seats
# - recliners
# - sofa beds
#
# The client is a low-cost retailer, offering many promotions and discounts. You will need to focus on such keywords. You will also need to move away from luxury keywords and topics, as you are targeting price-sensitive customers. Because they are going to be tight on budget, it would be good to focus on a tightly targeted set of keywords and make sure they are all set to exact and phrase match.
#
# Based on the brief above you will first need to generate a list of words, that together with the products given above would make for good keywords. Here are some examples:
#
# - Products: sofas, recliners
# - Words: buy, prices
#
# The resulting keywords: 'buy sofas', 'sofas buy', 'buy recliners', 'recliners buy', 'prices sofas', 'sofas prices', 'prices recliners', 'recliners prices'.
#
# As a final result, you want to have a DataFrame that looks like this:
#
# <table>
# <thead>
# <tr>
# <th>Campaign</th>
# <th>Ad Group</th>
# <th>Keyword</th>
# <th>Criterion Type</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1a</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1b</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_2</td>
# <td>keyword 2a</td>
# <td>Exact</td>
# </tr>
# </tbody>
# </table>

# %%
import pandas as pd

# %%
# Start coding here
# Use as many cells as you need

"""
Save at least 60 unique keywords as a DataFrame called keywords_df and a CSV file called keywords.csv.
Both of these should contain four columns:
Ad Group: containing the product names
Keyword: containing the product and keyword combinations, combined in both directions (word + product, and product + word)
Campaign: with the value SEM_Sofas in every row
Criterion Type: with the value Exact in every row.
"""

#List of words to pair with products
words =['buy','price','discount','promotion','promo','shop']
#print
print(words)
products =['sofas','convertible sofas','love seats','recliners','sofa beds']
#create an empty list
keywords_list=[]
#loop through products
for product in products:
    #Loop through words
    for word in words:
        keywords_list.append([product,product+' '+word])
#inspect keyword list
print(keywords_list)
#create dataframe from list
keywords_df = pd.DataFrame(keywords_list,columns=['Ad Group','Keyword'])
#print keywords DataFrame to explore it
print(keywords_df)
#Add a campaign column
keywords_df['Campaign']='SEM_Sofas'
#Add a criterion type column
keywords_df['Criterion Type'] = 'Exact'
#save the final keywords to a CSV file
keywords_df.to_csv('keywords.csv',index=False)
print(keywords_df)
# Out:
# ['buy', 'price', 'discount', 'promotion', 'promo', 'shop']
# [['sofas', 'sofas buy'], ['sofas', 'sofas price'], ['sofas', 'sofas discount'], ['sofas', 'sofas promotion'], ['sofas', 'sofas promo'], ['sofas', 'sofas shop'], ['convertible sofas', 'convertible sofas buy'], ['convertible sofas', 'convertible sofas price'], ['convertible sofas', 'convertible sofas discount'], ['convertible sofas', 'convertible sofas promotion'], ['convertible sofas', 'convertible sofas promo'], ['convertible sofas', 'convertible sofas shop'], ['love seats', 'love seats buy'], ['love seats', 'love seats price'], ['love seats', 'love seats discount'], ['love seats', 'love seats promotion'], ['love seats', 'love seats promo'], ['love seats', 'love seats shop'], ['recliners', 'recliners buy'], ['recliners', 'recliners price'], ['recliners', 'recliners discount'], ['recliners', 'recliners promotion'], ['recliners', 'recliners promo'], ['recliners', 'recliners shop'], ['sofa beds', 'sofa beds buy'], ['sofa beds', 'sofa beds price'], ['sofa beds', 'sofa beds discount'], ['sofa beds', 'sofa beds promotion'], ['sofa beds', 'sofa beds promo'], ['sofa beds', 'sofa beds shop']]
#              Ad Group                      Keyword
# 0               sofas                    sofas buy
# 1               sofas                  sofas price
# 2               sofas               sofas discount
# 3               sofas              sofas promotion
# 4               sofas                  sofas promo
# 5               sofas                   sofas shop
# 6   convertible sofas        convertible sofas buy
# 7   convertible sofas      convertible sofas price
# 8   convertible sofas   convertible sofas discount
# 9   convertible sofas  convertible sofas promotion
# 10  convertible sofas      convertible sofas promo
# 11  convertible sofas       convertible sofas shop
# 12         love seats               love seats buy
# 13         love seats             love seats price
# 14         love seats          love seats discount
# 15         love seats         love seats promotion
# 16         love seats             love seats promo
# 17         love seats              love seats shop
# 18          recliners                recliners buy
# 19          recliners              recliners price
# 20          recliners           recliners discount
# 21          recliners          recliners promotion
# 22          recliners              recliners promo
# 23          recliners               recliners shop
# 24          sofa beds                sofa beds buy
# 25          sofa beds              sofa beds price
# 26          sofa beds           sofa beds discount
# 27          sofa beds          sofa beds promotion
# 28          sofa beds              sofa beds promo
# 29          sofa beds               sofa beds shop
#              Ad Group                      Keyword   Campaign Criterion Type
# 0               sofas                    sofas buy  SEM_Sofas          Exact
# 1               sofas                  sofas price  SEM_Sofas          Exact
# 2               sofas               sofas discount  SEM_Sofas          Exact
# 3               sofas              sofas promotion  SEM_Sofas          Exact
# 4               sofas                  sofas promo  SEM_Sofas          Exact
# 5               sofas                   sofas shop  SEM_Sofas          Exact
# 6   convertible sofas        convertible sofas buy  SEM_Sofas          Exact
# 7   convertible sofas      convertible sofas price  SEM_Sofas          Exact
# 8   convertible sofas   convertible sofas discount  SEM_Sofas          Exact
# 9   convertible sofas  convertible sofas promotion  SEM_Sofas          Exact
# 10  convertible sofas      convertible sofas promo  SEM_Sofas          Exact
# 11  convertible sofas       convertible sofas shop  SEM_Sofas          Exact
# 12         love seats               love seats buy  SEM_Sofas          Exact
# 13         love seats             love seats price  SEM_Sofas          Exact
# 14         love seats          love seats discount  SEM_Sofas          Exact
# 15         love seats         love seats promotion  SEM_Sofas          Exact
# 16         love seats             love seats promo  SEM_Sofas          Exact
# 17         love seats              love seats shop  SEM_Sofas          Exact
# 18          recliners                recliners buy  SEM_Sofas          Exact
# 19          recliners              recliners price  SEM_Sofas          Exact
# 20          recliners           recliners discount  SEM_Sofas          Exact
# 21          recliners          recliners promotion  SEM_Sofas          Exact
# 22          recliners              recliners promo  SEM_Sofas          Exact
# 23          recliners               recliners shop  SEM_Sofas          Exact
# 24          sofa beds                sofa beds buy  SEM_Sofas          Exact
# 25          sofa beds              sofa beds price  SEM_Sofas          Exact
# 26          sofa beds           sofa beds discount  SEM_Sofas          Exact
# 27          sofa beds          sofa beds promotion  SEM_Sofas          Exact
# 28          sofa beds              sofa beds promo  SEM_Sofas          Exact
# 29          sofa beds               sofa beds shop  SEM_Sofas          Exact
